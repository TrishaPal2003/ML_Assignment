# %% [markdown]
# <a href="https://colab.research.google.com/github/TrishaPal2003/ML_Assignment/blob/main/ML_Assignment1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Name: Trisha Pal
#
# Email: trishapal160@gmail.com

# %% [markdown]
# # Question 1

# %%
import pandas as pd
df = pd.read_csv('titanic_data_updated.csv')

print(df.shape)

first_row=df.head(10)
print(first_row)

random_row=df.sample(5)
print(random_row)
# Out:
# (891, 12)
#    PassengerId Survived  Pclass  \
# 0            1       no   third
# 1            2      yes   first
# 2            3      yes   third
# 3            4      yes   first
# 4            5       no   third
# 5            6       no   third
# 6            7       no   first
# 7            8       no   third
# 8            9      yes   third
# 9           10      yes  second
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %% [markdown]
# # Question 2

# %%
df.isnull().sum()

df.duplicated().sum()

df.drop_duplicates(inplace=True)
df
# Out:
#      PassengerId Survived  Pclass  \
# 0              1       no   third
# 1              2      yes   first
# 2              3      yes   third
# 3              4      yes   first
# 4              5       no   third
# ..           ...      ...     ...
# 886          887       no  second
# 887          888      yes   first
# 888          889       no   third
# 889          890      yes   first
# 890          891       no   third
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# # Question 3

# %%
df.info()

df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    object
#  2   Pclass       891 non-null    object
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(3), object(7)
# memory usage: 83.7+ KB
#        PassengerId         Age       SibSp       Parch        Fare
# count   891.000000  714.000000  891.000000  891.000000  891.000000
# mean    446.000000   29.699118    0.523008    0.381594   32.204208
# ...

# %% [markdown]
# 1. Here two types of values one is numerical and another value is catagorical
#
# 2. There is no standared point in age column

# %% [markdown]
# # Question 4

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.countplot(data=df, x='Survived')
percentage = df['Survived'].value_counts(normalize=True) * 100
print(percentage)
# Out:
# Survived
# no     61.616162
# yes    38.383838
# Name: proportion, dtype: float64

# %%
survived_group = df.groupby('Survived').size()
plt.pie(survived_group, labels=survived_group.index, autopct='%1.1f%%',explode=(0.1,0),shadow=True)
plt.show()

# %% [markdown]
# 1. The number of non-survivor count is greater than survivor count
# 2. The survival rate is imbalanced

# %% [markdown]
# # Question 5

# %%
plt.hist(df['Age'])
# Out:
# (array([ 54.,  46., 177., 169., 118.,  70.,  45.,  24.,   9.,   2.]),
#  array([ 0.42 ,  8.378, 16.336, 24.294, 32.252, 40.21 , 48.168, 56.126,
#         64.084, 72.042, 80.   ]),
#  <BarContainer object of 10 artists>)

# %%
sns.kdeplot(data=df, x='Age')
# Out:
# <Axes: xlabel='Age', ylabel='Density'>

# %% [markdown]
# 1. here we see maximum people are 20 to 30 years old
#
# 2. in titanic dataset almost all age group of people traveled

# %% [markdown]
# # Question 6

# %%
sns.countplot(data=df, x='Sex', hue='Survived')

survival_ratio = df.groupby('Sex')['Survived'].value_counts(normalize=True) *100
print(survival_ratio)
# Out:
# Sex     Survived
# female  yes         74.203822
#         no          25.796178
# male    no          81.109185
#         yes         18.890815
# Name: proportion, dtype: float64

# %% [markdown]
# 1. here we see female suvive rate is higher then male

# %% [markdown]
# # Question 7

# %%
sns.barplot(data=df, x='Pclass', y='Fare')
# Out:
# <Axes: xlabel='Pclass', ylabel='Fare'>

# %% [markdown]
# 1. here showed the first class passenger paid significantly higher
#
# 2. second and third class passengers paid relatively similar fares

# %% [markdown]
# # Question 8

# %%
sns.kdeplot(data=df, x='Age', hue='Survived')
# Out:
# <Axes: xlabel='Age', ylabel='Density'>

# %% [markdown]
# 1. Both non-survivor and survivor passengers are present in 20 to 40 age group
# 2. The number of non survival count is smaller than survival count

# %% [markdown]
# # Question 9

# %%
from sklearn.model_selection import train_test_split
df.drop(['PassengerId','Name','Ticket'],axis=1,inplace=True)
x = df.drop('Survived', axis=1)
y = df['Survived']
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2,random_state=42)

print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (712, 8)
# (179, 8)
# (712,)
# (179,)

# %% [markdown]
# # Question 10

# %%
import numpy as np
from sklearn.impute import SimpleImputer

age_imputer = SimpleImputer(missing_values=np.nan,strategy='mean')
age_imputer.fit(x_train[['Age']])
x_train['Age'] = age_imputer.transform(x_train[['Age']]).ravel()
x_train['Age'] = age_imputer.transform(x_train[['Age']]).ravel()


embarked_imputer = SimpleImputer(missing_values=np.nan,strategy='most_frequent')
embarked_imputer.fit(x_train[['Embarked']])
x_train['Embarked'] = embarked_imputer.transform(x_train[['Embarked']]).ravel()
x_test['Embarked'] = embarked_imputer.transform(x_test[['Embarked']]).ravel()

Cabin_imputer = SimpleImputer(missing_values=np.nan,strategy='constant')
Cabin_imputer.fit(x_train[['Cabin']])
x_train['Cabin'] = Cabin_imputer.transform(x_train[['Cabin']]).ravel()
x_test['Cabin'] = Cabin_imputer.transform(x_test[['Cabin']]).ravel()

x_train.isnull().sum()
x_test.isnull().sum()
# Out:
# Pclass       0
# Sex          0
# Age         37
# SibSp        0
# Parch        0
# Fare         0
# Cabin        0
# Embarked     0
# dtype: int64
